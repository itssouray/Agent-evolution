# %%
import sys
from pathlib import Path

sys.path.append(
    str(Path.cwd().parent)
)

# %%
from src.state.reflection_state import AgentState
from src.agents.reflection.planner import Planner
from src.agents.reflection.executer import Executor

# %%
goal = "Research the current president and secretary of BCCI"
planner = Planner()
executor = Executor()
state = AgentState(goal)

# %%
state = planner.create_plan(state)
state = executor.execute(state)


print(state)
# Out:
# Executing: Find the current president of BCCI
#
# LLM OUTPUT:
# Thought: I need to look up the most recent and verified information about the current president of the BCCI.
# Action: search
# Action Input: current president of BCCI
#
# LLM OUTPUT:
# Thought: There is conflicting information in the sources. Roger Binny was noted as the president from October 2022, but recent news indicates Mithun Manhas has become the new president, replacing Roger Binny.
# Final Answer: The current president of the BCCI is Mithun Manhas.
# {
#     "success": false,
#     "feedback": "The answer is incorrect. The current president of the BCCI is Roger Binny, not Mithun Manhas."
# }
#
# Executing: Find the current secretary of BCCI
#
# LLM OUTPUT:
# Thought: The search results mention Devajit Saikia as the current Secretary of BCCI. I will confirm this information from the sources provided.
# Final Answer: Devajit Saikia is the current Secretary of the Board of Control for Cricket in India (BCCI).
# {
# ...

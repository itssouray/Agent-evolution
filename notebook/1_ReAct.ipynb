# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent

sys.path.append(str(project_root))

# %%
import importlib
import src.agents.react_agent

importlib.reload(src.agents.react_agent)
# Out:
# <module 'src.agents.react_agent' from '/home/sourav/Program/backup-sourav/programe/AI/Agents/Agent_Evolution/src/agents/react_agent.py'>

# %%
from src.agents.react_agent import ReAct_Agent

agent = ReAct_Agent()

answer = agent.run(
    "Who won the last IPL and who was the captain?"
)

print(answer)
# Out:
# LLM OUTPUT:
# Thought: I need to find out the winner of the most recent IPL (Indian Premier League) and their captain.
#
# Action: search
#
# Action Input: last IPL winner and captain
#
# LLM OUTPUT:
# Thought: From the observations, it's clear that the Royal Challengers Bengaluru (RCB) won the last IPL (2026), defeating Gujarat Titans in the final. However, the specific name of the RCB captain in the 2026 season is not explicitly mentioned in the provided information. I need to confirm who captained RCB in IPL 2026.
#
# Action: search
#
# Action Input: Royal Challengers Bengaluru captain 2026 IPL
#
# LLM OUTPUT:
# Thought: The searched information confirms that Rajat Patidar was the captain of Royal Challengers Bengaluru (RCB) when they won the 2026 IPL.
#
# Final Answer: The last IPL (2026) was won by Royal Challengers Bengaluru, and their captain was Rajat Patidar.
# The last IPL (2026) was won by Royal Challengers Bengaluru, and their captain was Rajat Patidar.

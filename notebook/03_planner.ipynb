# %%
import sys
from pathlib import Path

sys.path.append(
    str(Path.cwd().parent)
)

# %%
from src.agents.planning.planner import Planner
from src.agents.planning.executer import Executor


planner = Planner()
executor = Executor()


tasks = planner.create_plan(
    "Research the BCCI Board and Members in BCCI"
)


results = executor.execute(tasks)

for item in results:
    print(item)

# %% [markdown]
# ### State Management

# %%
from src.state.agent_state import AgentState
from src.agents.planning.planner import Planner
from src.agents.planning.executer import Executor


Planner = planner_module.Planner


planner = Planner()
executor = Executor()
goal = "Research the BCCI Board and Members in BCCI"


state = AgentState(goal)

state = planner.create_plan(state)

state = executor.execute(state)

print(state.results)
# Out:
# [
#     "Find the full form and role of BCCI",
#     "Research the structure of the BCCI Board",
#     "Identify current members of the BCCI Board",
#     "Find the roles and responsibilities of each BCCI Board member",
#     "Gather recent news or updates about the BCCI Board",
#     "Create final response summarizing BCCI Board and its members"
# ]
# ['Find the full form and role of BCCI', 'Research the structure of the BCCI Board', 'Identify current members of the BCCI Board', 'Find the roles and responsibilities of each BCCI Board member', 'Gather recent news or updates about the BCCI Board', 'Create final response summarizing BCCI Board and its members']
#
# Executing: Find the full form and role of BCCI
#
# LLM OUTPUT:
# Thought: The user is asking for the full form and the role of BCCI. I know BCCI is a prominent organization related to cricket in India, but to ensure accuracy and provide a detailed response, I should verify with a quick search.
#
# Action: search
#
# ...
